# %%
import torch

networkPath = "/mnt/workspace/FBCNet/output/bci42a/2023-11-28--10-57-117/FBCNet/best_model.pth"
checkpoint = torch.load(networkPath)
checkpoint
# Out:
# {'epoch': 549,
#  'model_state_dict': OrderedDict([('scb.0.weight',
#                tensor([[[[-0.1779],
#                          [-0.0043],
#                          [ 0.4942],
#                          ...,
#                          [-0.1644],
#                          [ 0.3194],
#                          [ 0.1383]]],
#
#
#                        [[[-0.1926],
#                          [-0.7207],
#                          [ 0.3492],
#                          ...,
#                          [ 0.2742],
#                          [ 0.7233],
#                          [-0.4147]]],
#
#
#                        [[[ 0.2542],
#                          [-0.2027],
#                          [-0.2667],
#                          ...,
#                          [-0.7268],
#                          [ 0.2740],
#                          [ 0.5013]]],
#
#
#                        ...,
#
#
#                        [[[ 0.0641],
#                          [ 0.4970],
# ...
